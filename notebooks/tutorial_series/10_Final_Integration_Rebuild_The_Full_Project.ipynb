# %% [markdown]
# # 10. Final Project: Audience Engagement Dashboard
#
# **Goal:** Put it all together.

# %% [markdown]
# ## 1. The Architecture
# 1.  **Capture**
# 2.  **Detect** (Face + Iris)
# 3.  **Signal Logic** (Yaw/Pitch/EAR)
# 4.  **Aggregation** (Count totals)
# 5.  **Smoothing** (Buffer)
# 6.  **Display** (UI Overlay)
# 7.  **Log** (CSV)

# %% [markdown]
# ## 2. Run the Full App

# %%
# Run the accompanying 'create_notebook.py' script (or the project file we built together)
# to generate the final .ipynb file.
